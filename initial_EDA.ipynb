# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("train.csv")
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
df.sample(10)
# Out:
#             id    qid1    qid2  \
# 88423    88423  138497  148723
# 379279  379279  111181  284751
# 236734  236734  347723  347724
# 141729  141729  224918  224919
# 56926    56926  100128  100129
# 73779    73779  126554  126555
# 135702  135702  216652  216653
# 6654      6654   13027   13028
# 161477  161477  251614  251615
# 160450  160450    2068  198755
#
#                                                 question1  \
# 88423   How do I install Android apps directly to an S...
# 379279  How one can lose weight without going to the gym?
# 236734  We are a registered company in Delaware. We ar...
# 141729  Why is a video not showing on YouTube and how ...
# 56926   Could we drill a hole to the earth's core, how...
# 73779                      Inorganic chemistry aman goel?
# 135702  Which is the best ethical hacking institute in...
# 6654                            What caused the Big Bang?
# 161477  How do I choose a transactional SMS provider i...
# 160450  What hotel in Shimla Hill-station would be saf...
#
#                                                 question2  is_duplicate
# 88423   How can I connect USB devices to my Android ph...             0
# 379279            Can I lose weight without going to gym?             1
# 236734    How do I get an international merchant account?             0
# 141729  Why are Youtube videos not playing? How can I ...             1
# 56926   How much of the Earth integrity will be at ris...             0
# 73779   Http://www.fitclown.com/medi-wei... #medi #wei...             0
# 135702  Which is the best institute for ethical hackin...             1
# 6654            Which elements collision caused big bang?             1
# 161477  Which is the best transactional SMS provider i...             0
# 160450  What hotel in The Sivalik Hills Hill-station w...             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            404290 non-null  int64
#  1   qid1          404290 non-null  int64
#  2   qid2          404290 non-null  int64
#  3   question1     404289 non-null  object
#  4   question2     404288 non-null  object
#  5   is_duplicate  404290 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %%
df.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df['is_duplicate'].value_counts())
print((df['is_duplicate'].value_counts()/df['is_duplicate'].count())*100)
df['is_duplicate'].value_counts().plot(kind='bar')
# Out:
# is_duplicate
# 0    255027
# 1    149263
# Name: count, dtype: int64
# is_duplicate
# 0    63.080215
# 1    36.919785
# Name: count, dtype: float64
# <Axes: xlabel='is_duplicate'>

# %%
qid = pd.Series(df['qid1'].tolist() + df['qid2'].tolist())
print('Number of unique questions',np.unique(qid).shape[0])
x = qid.value_counts()>1
print('Number of questions getting repeated',x[x].shape[0])
# Out:
# Number of unique questions 537933
# Number of questions getting repeated 111780

# %%
plt.hist(qid.value_counts().values,bins=160)
plt.yscale('log')
plt.show()
